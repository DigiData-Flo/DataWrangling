# %% [markdown]
# #### Quaility
#
# ##### DataFrame twitter_df
#
# * ~~Erroneous Data Type: timestamp should be datetime~~
# * Check rating_numerator and rating_enumerator
# * ~~The Source column contains is a hole html anker element~~
# * The name column contains a lot of None as name
# * Remove rows with notnull for retweeded_status_id.
#
# ##### DataFrame tweet_df
#
# * ~~column language contains only abbreviations~~
# * ~~column language shows, that there are undefined languages.~~
#
#
# ##### DataFrame language_df
#
# * ~~Dataframe Contains dupicate rows~~
# * ~~Language DataFrame columns have whitespaces~~
#
# ##### DataFrame prediction_df
#
# * ~~The dog breed names have an underscore instead a space inside and lower and uppercase ist mixed.~~
# * ~~The dog columns contains false values for not dog classified pictures.~~
#
# #### Tidiness
#
# * ~~Different row counts for the used Data Frames~~
# * ~~One variable in three columns. The twitter_df columns doggo, floofer, pupper, puppo are values from variable dog_descritption~~
# * ~~Duplicate columns in_reply_to_user_id and in_reply_to_status_id in twitter_df and tweet_df~~
# * ~~Different counts of in_reply items~~
# * ~~The columns in_reply... are now original tweets, they are only retweets.~~
# * ~~The prediction_df contain 3 times p1, p1_conf, p1_dog as p1, p2 and p3.~~

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'


labels = ['G1', 'G2', 'G3', 'G4', 'G5']
men_means = [20, 34, 30, 35, 27]
women_means = [25, 32, 34, 20, 25]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, men_means, width, label='Men')
rects2 = ax.bar(x + width/2, women_means, width, label='Women')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Scores')
ax.set_title('Scores by group and gender')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

#ax.bar_label(rects1, padding=3)
#ax.bar_label(rects2, padding=3)

fig.tight_layout()

plt.savefig('scores.png')

plt.show()
